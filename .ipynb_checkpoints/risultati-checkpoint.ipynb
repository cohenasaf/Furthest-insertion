# - nearestInsertion
# - cheapestInsertion
# - nearestNeighbor
# - farthestInsertion
# - furthestInsertion
# - Optimal
# - Nome del tsp

# %%
r
# Out:
# [('d198',
#   1.062433829658095,
#   1.1360454545949497,
#   1.115192865965115,
#   1.2180456604337535,
#   1.0302623546152974,
#   1.0617900495472332),
#  ('lin318',
#   1.1080381296482789,
#   1.2443578764303436,
#   1.2418492656827038,
#   1.2856260385277645,
#   1.0915020294829432,
#   1.0998295205588327),
#  ('fl417',
#   1.0816987591918856,
#   1.2520395301379346,
#   1.2602859529310952,
#   1.2807590521365082,
#   1.0812761498048593,
#   1.088512900793671),
#  ('pcb442',
#   1.1590920990074574,
#   1.1982723362653798,
#   1.21905297363948,
#   1.2206870545691801,
#   1.1371343272562013,
#   1.1251808980844065),
#  ('u574',
#   1.1064941729910707,
#   1.2232127382809193,
#   1.229510729311989,
#   1.3837703550046516,
#   1.1006370718670588,
#   1.1115182881270869),
#  ('p654',
#   1.061189284802174,
#   1.2126837319868062,
#   1.2016004119323607,
#   1.2530816604201624,
#   1.031160077511625,
#   1.0640032711395835),
#  ('rat783',
#   1.1333756526807082,
# ...

# %% [markdown]
# Calcolo in media, di quanto le euristiche si discostano dall'ottimo (in percentuale)

# %%
rI, nI, cI, nN, faI, fuI = 0, 0, 0, 0, 0, 0
for i in r:
    rI += i[0] / i[6]
    nI += i[1] / i[6]
    cI += i[2] / i[6]
    nN += i[3] / i[6]
    faI += i[4] / i[6]
    fuI += i[5] / i[6]
rI /= len(r)
nI /= len(r)
cI /= len(r)
nN /= len(r)
faI /= len(r)
fuI /= len(r)
print("randomInsertion\t\t{}%\nnearestInsertion\t{}%\ncheapestInsertion\t{}%\nnearestNeabour\t\t{}%\nfarthestInsertion\t{}%\nfurthestInsertion\t{}%".format(rI, nI, cI, nN, faI, fuI))
# Out:
# randomInsertion		1.1091568409473387%
# nearestInsertion	1.2107855871419055%
# cheapestInsertion	1.2131783575060766%
# nearestNeabour		1.2777776321343715%
# farthestInsertion	1.088162386605272%
# furthestInsertion	1.097366331422246%

# %% [markdown]
# Ora invece la varianza di quanto le euristiche si discostano dall'ottimo (sempre in percentuale)

# %%
import numpy as np
rI, nI, cI, nN, faI, fuI = [], [], [], [], [], []
for i in r:
    rI.append(i[1])
    nI.append(i[2])
    cI.append(i[3])
    nN.append(i[4])
    faI.append(i[5]) 
    fuI.append(i[6])
print(np.mean(rI))
print(np.mean(nI))
print(np.mean(cI))
print(np.mean(nN))
print(np.mean(faI))
print(np.mean(fuI))
print(
print(np.var(rI))
print(np.var(nI))
print(np.var(cI))
print(np.var(nN))
print(np.var(faI))
print(np.var(fuI))
# Out:
# 1.1392253869627122
# 1.2199243381138396
# 1.2203657637703693
# 1.2578577807156632
# 1.131938836481005
# 1.1542317278016556
# 0.0016914485363462906
# 0.0013983266580573936
# 0.0011285319236157235
# 0.0025113017700919876
# 0.0028131392170019005
# 0.0028734068777577153
