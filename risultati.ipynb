# %% [markdown]
# I risultati sono nell'ordine:
# - randomInsertion
# - nearestInsertion
# - cheapestInsertion
# - nearestNeighbor
# - farthestInsertion
# - furthestInsertion
# - Optimal
# - Nome del tsp

# %%
r
# Out:
# [(450.2787983503308,
#   490.6328447037737,
#   538.283201758926,
#   513.610006884723,
#   470.2943524231006,
#   464.53668235617306,
#   426,
#   'eil51'),
#  (459.97778262433775,
#   490.6328447037737,
#   538.283201758926,
#   513.610006884723,
#   470.2943524231006,
#   464.53668235617306,
#   426,
#   'eil51'),
#  (581.3708767682837,
#   619.7798394718341,
#   617.6259607809698,
#   711.993292632752,
#   585.6670492849571,
#   608.5354802427684,
#   538,
#   'eil76'),
#  (595.5226886411771,
#   619.7798394718341,
#   617.6259607809698,
#   711.993292632752,
#   585.6670492849571,
#   608.5354802427684,
#   538,
#   'eil76'),
#  (694.2258020131827,
#   816.9695462452087,
#   794.4169351244748,
#   805.5312008437772,
#   725.1862604856153,
#   710.3597936254151,
#   675,
#   'st70'),
#  (709.7857447327796,
#   816.9695462452087,
#   794.4169351244748,
#   805.5312008437772,
#   725.1862604856153,
#   710.3597936254151,
#   675,
#   'st70'),
#  (721.8470120886548,
# ...

# %% [markdown]
# Calcolo in media, di quanto le euristiche si discostano dall'ottimo (in percentuale)

# %%
rI, nI, cI, nN, faI, fuI = 0, 0, 0, 0, 0, 0
for i in r:
    rI += i[0] / i[6]
    nI += i[1] / i[6]
    cI += i[2] / i[6]
    nN += i[3] / i[6]
    faI += i[4] / i[6]
    fuI += i[5] / i[6]
rI /= len(r)
nI /= len(r)
cI /= len(r)
nN /= len(r)
faI /= len(r)
fuI /= len(r)
print("randomInsertion\t\t{}%\nnearestInsertion\t{}%\ncheapestInsertion\t{}%\nnearestNeabour\t\t{}%\nfarthestInsertion\t{}%\nfurthestInsertion\t{}%".format(rI, nI, cI, nN, faI, fuI))
# Out:
# randomInsertion		1.0962566357125532%
# nearestInsertion	1.2127775635098208%
# cheapestInsertion	1.207709068409696%
# nearestNeabour		1.2416731508463468%
# farthestInsertion	1.0873416236949196%
# furthestInsertion	1.1022911867203167%

# %% [markdown]
# Ora invece la varianza di quanto le euristiche si discostano dall'ottimo (sempre in percentuale)

# %%
import numpy as np
rI, nI, cI, nN, faI, fuI = [], [], [], [], [], []
for i in r:
    rI.append(i[0] / i[6])
    nI.append(i[1] / i[6])
    cI.append(i[2] / i[6])
    nN.append(i[3] / i[6])
    faI.append(i[4] / i[6]) 
    fuI.append(i[5] / i[6])
print(np.var(rI))
print(np.var(nI))
print(np.var(cI))
print(np.var(nN))
print(np.var(faI))
print(np.var(fuI))
# Out:
# 0.0011648545897561184
# 0.0019439200044680082
# 0.0019186717821476139
# 0.005184815518815984
# 0.0008952950703123802
# 0.002406631178240403
