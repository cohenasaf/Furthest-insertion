# %%
randomInsertion = [0.03, 0.07, 0.13, 0.14, 0.23, 0.32, 0.44, 0.71, 0.84, 1.03, 1.21, 1.30, 1.46, 1.50, 1.79, 2.05, 2.29, 2.63, 3.39, 4.16, 6.81, 10.94]
nearestNeighbor = [0.01, 0.02, 0.04, 0.05, 0.08, 0.10, 0.15, 0.24, 0.26, 0.33, 0.41, 0.43, 0.49, 0.51, 0.59, 0.67, 0.79, 0.85, 1.09, 1.37, 2.25, 3.59]
nearestInsertion = [0.04, 0.11, 0.19, 0.23, 0.36, 0.47, 0.64, 1.09, 1.23, 1.47, 1.77, 1.89, 2.13, 2.11, 2.64, 2.94, 3.28, 3.86, 4.85, 5.95, 9.84, 15.68]
cheapestInsertion = [0.11, 0.27, 0.48, 0.54, 0.84, 1.20, 1.64, 2.66, 3.02, 3.50, 4.90, 4.97, 5.35, 5.08, 6.27, 7.44, 8.29, 11.61, 12.07, 14.84, 24.26, 49.71]
farthestInsertion = [0.05, 0.12, 0.19, 0.24, 0.43, 0.50, 0.70, 1.16, 1.34, 1.63, 1.87, 2.03, 2.28, 2.37, 2.81, 3.26, 3.62, 4.17, 5.21, 6.64, 10.85, 16.91]
furthestInsertion = [0.10, 0.25, 0.48, 0.48, 0.85, 1.09, 1.53, 2.61, 2.98, 3.53, 4.39, 4.61, 5.17, 5.29, 6.35, 7.17, 7.78, 9.35, 11.96, 14.77, 24.34, 39.48]

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generating sample data
x = np.linspace(0, len(randomInsertion), len(randomInsertion))
y1 = np.array(randomInsertion)
y2 = np.array(nearestNeighbor)
y3 = np.array(nearestInsertion)
y4 = np.array(cheapestInsertion)
y5 = np.array(farthestInsertion)
y6 = np.array(furthestInsertion)

# Plotting with different line styles
plt.figure(figsize=(10, 6))

plt.plot(x, y1, label='randomInsertion', linestyle='-', color='blue')  # Solid line
plt.plot(x, y2, label='nearestNeighbor', linestyle='--', color='red')  # Dashed line
plt.plot(x, y3, label='nearestInsertion', linestyle='-.', color='green')  # Dash-dot line
plt.plot(x, y4, label='cheapestInsertion', linestyle=':', color='purple')  # Dotted line
plt.plot(x, y5, label='farthestInsertion', linestyle=':', color='purple')  # Dotted line
plt.plot(x, y6, label='furthestInsertion', linestyle='-', color='orange', linewidth=2, dash_capstyle='round', dash_joinstyle='round')  # Solid line with custom width and cap/join style

plt.ylim(0, 55)  # Limiting y-axis values for better visualization, especially for tan(x)
plt.xlabel('...')
plt.ylabel('Tempi in secondi')
plt.title('Plot dei tempi per alcune euristiche per il TSP')
plt.legend()
plt.grid(True)
plt.show()
